# %%
import pandas as pd
df = pd.read_csv('sales.csv')
df.head()
#df.tail(2)
# Out:
#          Date Region Product  Units_Sold  Unit_Price
# 0  2024-05-01   East  Laptop           5         700
# 1  2024-05-01   West   Phone          10         300
# 2  2024-05-02   East  Laptop           6         700
# 3  2024-05-02   West   Phone           8         300

# %%
df.to_csv("exported_sales.csv",index=False)

# %%
import pandas as pd
df = pd.read_excel("employee_data.xlsx")
df.head()
# Out:
#    Emp_ID     Name Department
# 0     101    Alice         HR
# 1     102      Bob    Finance
# 2     103  Charlie         IT
# 3     104    David      Sales

# %%
df.to_excel("exported_employee.xlsx",index=False)

# %%
import pandas as pd
df = pd.read_excel("employee_data.xlsx")
df.head()
df.to_csv("converted_employee.csv",index=False)
